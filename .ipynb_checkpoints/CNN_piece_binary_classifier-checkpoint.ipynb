# %%
# piece classifier

import os
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from Creator_dataset import Creator_dataset
from tensorflow.keras import datasets, layers, models
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
# from keras_visualizer import visualizer 
#new
import tensorflow_addons as tfa
from focal_loss import BinaryFocalLoss

# %%
AUTOTUNE = tf.data.AUTOTUNE
creator_dataset = Creator_dataset(32) 
#train_ds, val_ds, test_ds = creator_dataset.create_dataset("piece_equal")
#train_ds, val_ds, test_ds = creator_dataset.create_dataset("piece")
test_ds = creator_dataset.create_dataset("piece", "piece_test")
val_ds = creator_dataset.create_dataset("piece", "piece_val")
train_ds = creator_dataset.create_dataset("piece", "piece_train")

image_batch_train, label_batch_train = next(iter(train_ds))
image_batch_test, label_batch_test = next(iter(test_ds))
image_batch_val, label_batch_val = next(iter(val_ds))

image_train = np.concatenate([x1 for x1, y1 in train_ds], axis=0)
label_train = np.concatenate([y2 for x2, y2 in train_ds], axis=0)
image_val = np.concatenate([x for x, y in val_ds], axis=0)
label_val = np.concatenate([y for x, y in val_ds], axis=0)
image_test = np.concatenate([x for x, y in test_ds], axis=0)
label_test = np.concatenate([y for x, y in test_ds], axis=0)
# Out:
# --------------------
# Dataset <built-in function dir>
# piece_test	3000	94 bt. x 32 bt.size: done
# --------------------
# --------------------
# Dataset <built-in function dir>
# piece_val	3000	94 bt. x 32 bt.size: done
# --------------------
# --------------------
# Dataset <built-in function dir>
# piece_train	31200	975 bt. x 32 bt.size: done
# --------------------

# %%
## Transforming labels to correct format
num_classes = 12
label_train = to_categorical(label_train, num_classes=num_classes)
label_test = to_categorical(label_test, num_classes=num_classes)
label_val = to_categorical(label_val, num_classes=num_classes)
label_batch_train = to_categorical(label_batch_train, num_classes=num_classes)
label_batch_test = to_categorical(label_batch_test, num_classes=num_classes)
label_batch_val = to_categorical(label_batch_val, num_classes=num_classes)

# Achtung mit der Batchsize
# print(image_train.shape)
# print(label_train.shape)
# print(image_val.shape)
# print(label_val.shape)
# print(image_test.shape)
# print(label_test.shape)

train_dataset = train_ds.prefetch(buffer_size=AUTOTUNE)
validation_dataset = val_ds.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
pd.DataFrame({"piece": [char for char in 'RNBQKPrnbqkp'],
             "freq_tr" : list(sum(label_train)),
             "freq_te" : list(sum(label_test)),
             "freq_va" : list(sum(label_val))})
# Out:
#    piece  freq_tr  freq_te  freq_va
# 0      R   2600.0    250.0    250.0
# 1      N   2600.0    250.0    250.0
# 2      B   2600.0    250.0    250.0
# 3      Q   2600.0    250.0    250.0
# 4      K   2600.0    250.0    250.0
# 5      P   2600.0    250.0    250.0
# 6      r   2600.0    250.0    250.0
# 7      n   2600.0    250.0    250.0
# 8      b   2600.0    250.0    250.0
# 9      q   2600.0    250.0    250.0
# 10     k   2600.0    250.0    250.0
# 11     p   2600.0    250.0    250.0

# %%
#CNN
model = tf.keras.models.Sequential([
tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(100, 100, 3)),
tf.keras.layers.MaxPooling2D(2, 2),
tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(12, activation='softmax')])


model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              #loss=BinaryFocalLoss(gamma=2),
              metrics=['accuracy'])

# %%
# model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

history = model.fit(image_train, 
                    label_train, 
                    epochs=75, 
                    validation_data=(image_val, label_val),
                    callbacks=[callback])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# Epoch 1/100
# /home/clusterusers/rriege/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 975/975 [==============================] - 9s 7ms/step - loss: 0.2656 - accuracy: 0.2054 - val_loss: 0.2149 - val_accuracy: 0.3507
# Epoch 2/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.1984 - accuracy: 0.4298 - val_loss: 0.1780 - val_accuracy: 0.5177
# Epoch 3/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.1635 - accuracy: 0.5637 - val_loss: 0.1467 - val_accuracy: 0.6187
# Epoch 4/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.1358 - accuracy: 0.6617 - val_loss: 0.1267 - val_accuracy: 0.6910
# Epoch 5/100
# 975/975 [==============================] - 6s 7ms/step - loss: 0.1147 - accuracy: 0.7255 - val_loss: 0.1086 - val_accuracy: 0.7560
# Epoch 6/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0965 - accuracy: 0.7837 - val_loss: 0.0939 - val_accuracy: 0.7873
# Epoch 7/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0837 - accuracy: 0.8198 - val_loss: 0.0835 - val_accuracy: 0.8160
# Epoch 8/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0715 - accuracy: 0.8516 - val_loss: 0.0716 - val_accuracy: 0.8513
# Epoch 9/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0623 - accuracy: 0.8739 - val_loss: 0.0643 - val_accuracy: 0.8683
# Epoch 10/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0557 - accuracy: 0.8904 - val_loss: 0.0692 - val_accuracy: 0.8553
# Epoch 11/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0488 - accuracy: 0.9071 - val_loss: 0.0553 - val_accuracy: 0.8897
# Epoch 12/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0444 - accuracy: 0.9181 - val_loss: 0.0586 - val_accuracy: 0.8827
# Epoch 13/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0393 - accuracy: 0.9287 - val_loss: 0.0501 - val_accuracy: 0.9040
# Epoch 14/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0372 - accuracy: 0.9324 - val_loss: 0.0547 - val_accuracy: 0.8917
# Epoch 15/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0340 - accuracy: 0.9404 - val_loss: 0.0465 - val_accuracy: 0.9133
# Epoch 16/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0316 - accuracy: 0.9433 - val_loss: 0.0458 - val_accuracy: 0.9170
# Epoch 17/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0295 - accuracy: 0.9479 - val_loss: 0.0526 - val_accuracy: 0.8977
# Epoch 18/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0274 - accuracy: 0.9526 - val_loss: 0.0466 - val_accuracy: 0.9147
# Epoch 19/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0270 - accuracy: 0.9562 - val_loss: 0.0460 - val_accuracy: 0.9237
# Epoch 20/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0243 - accuracy: 0.9586 - val_loss: 0.0456 - val_accuracy: 0.9140
# Epoch 21/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0228 - accuracy: 0.9622 - val_loss: 0.0488 - val_accuracy: 0.9107
# Epoch 22/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0231 - accuracy: 0.9617 - val_loss: 0.0432 - val_accuracy: 0.9193
# Epoch 23/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0219 - accuracy: 0.9643 - val_loss: 0.0424 - val_accuracy: 0.9230
# Epoch 24/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0207 - accuracy: 0.9667 - val_loss: 0.0412 - val_accuracy: 0.9223
# Epoch 25/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0179 - accuracy: 0.9734 - val_loss: 0.0405 - val_accuracy: 0.9330
# Epoch 26/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0190 - accuracy: 0.9698 - val_loss: 0.0397 - val_accuracy: 0.9290
# Epoch 27/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0173 - accuracy: 0.9737 - val_loss: 0.0429 - val_accuracy: 0.9250
# Epoch 28/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0174 - accuracy: 0.9738 - val_loss: 0.0484 - val_accuracy: 0.9217
# Epoch 29/100
# 975/975 [==============================] - 6s 7ms/step - loss: 0.0163 - accuracy: 0.9754 - val_loss: 0.0419 - val_accuracy: 0.9327
# Epoch 30/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0171 - accuracy: 0.9740 - val_loss: 0.0443 - val_accuracy: 0.9270
# Epoch 31/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0163 - accuracy: 0.9756 - val_loss: 0.0375 - val_accuracy: 0.9357
# Epoch 32/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0157 - accuracy: 0.9766 - val_loss: 0.0429 - val_accuracy: 0.9300
# Epoch 33/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0146 - accuracy: 0.9790 - val_loss: 0.0407 - val_accuracy: 0.9347
# Epoch 34/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0147 - accuracy: 0.9786 - val_loss: 0.0488 - val_accuracy: 0.9247
# Epoch 35/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0143 - accuracy: 0.9789 - val_loss: 0.0442 - val_accuracy: 0.9273
# Epoch 36/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0138 - accuracy: 0.9804 - val_loss: 0.0411 - val_accuracy: 0.9353
# Epoch 37/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0134 - accuracy: 0.9803 - val_loss: 0.0464 - val_accuracy: 0.9290
# Epoch 38/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0135 - accuracy: 0.9802 - val_loss: 0.0440 - val_accuracy: 0.9287
# Epoch 39/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0136 - accuracy: 0.9804 - val_loss: 0.0412 - val_accuracy: 0.9347
# Epoch 40/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0124 - accuracy: 0.9830 - val_loss: 0.0453 - val_accuracy: 0.9280
# Epoch 41/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0124 - accuracy: 0.9826 - val_loss: 0.0439 - val_accuracy: 0.9287
# Epoch 42/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0117 - accuracy: 0.9838 - val_loss: 0.0451 - val_accuracy: 0.9317
# Epoch 43/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0119 - accuracy: 0.9831 - val_loss: 0.0450 - val_accuracy: 0.9330
# Epoch 44/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0108 - accuracy: 0.9856 - val_loss: 0.0437 - val_accuracy: 0.9343
# Epoch 45/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0118 - accuracy: 0.9839 - val_loss: 0.0568 - val_accuracy: 0.9170
# Epoch 46/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0112 - accuracy: 0.9854 - val_loss: 0.0416 - val_accuracy: 0.9417
# Epoch 47/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0106 - accuracy: 0.9860 - val_loss: 0.0428 - val_accuracy: 0.9353
# Epoch 48/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0116 - accuracy: 0.9837 - val_loss: 0.0431 - val_accuracy: 0.9373
# Epoch 49/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0107 - accuracy: 0.9857 - val_loss: 0.0456 - val_accuracy: 0.9350
# Epoch 50/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0100 - accuracy: 0.9876 - val_loss: 0.0447 - val_accuracy: 0.9367
# Epoch 51/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0092 - accuracy: 0.9891 - val_loss: 0.0536 - val_accuracy: 0.9253
# Epoch 52/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0109 - accuracy: 0.9856 - val_loss: 0.0408 - val_accuracy: 0.9400
# Epoch 53/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0098 - accuracy: 0.9881 - val_loss: 0.0435 - val_accuracy: 0.9397
# Epoch 54/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0101 - accuracy: 0.9872 - val_loss: 0.0456 - val_accuracy: 0.9283
# Epoch 55/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0106 - accuracy: 0.9862 - val_loss: 0.0441 - val_accuracy: 0.9347
# Epoch 56/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0081 - accuracy: 0.9904 - val_loss: 0.0399 - val_accuracy: 0.9417
# Epoch 57/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0090 - accuracy: 0.9889 - val_loss: 0.0455 - val_accuracy: 0.9377
# Epoch 58/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0095 - accuracy: 0.9878 - val_loss: 0.0470 - val_accuracy: 0.9340
# Epoch 59/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0092 - accuracy: 0.9881 - val_loss: 0.0418 - val_accuracy: 0.9370
# Epoch 60/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0092 - accuracy: 0.9881 - val_loss: 0.0415 - val_accuracy: 0.9450
# Epoch 61/100
# 975/975 [==============================] - 6s 6ms/step - loss: 0.0083 - accuracy: 0.9904 - val_loss: 0.0528 - val_accuracy: 0.9310

# %%
test_loss, test_acc = model.evaluate(image_test,  label_test, verbose=2)

print(test_loss)
print(test_acc)
# Out:
# 94/94 - 0s - loss: 0.0635 - accuracy: 0.9360 - 339ms/epoch - 4ms/step
# 0.06347521394491196
# 0.9359999895095825

# %%
model.summary()
model.save("models/CNN_binary_stable")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 512)               33280
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 12)                6156
#
# =================================================================
# Total params: 136,876
# Trainable params: 136,876
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Assets written to: models/CNN_binary_stable/assets

# %%
predictions = model.predict(image_test)
pred_bool = list(predictions)
print(np.argmax(pred_bool[0]))
# Out:
# 5

# %%
#predlist = predictions.tolist()
#predlist2 = [x[0] for x in predlist]

# pred = pd.DataFrame({"pred": predlist2, "lab": label_test})

# pred["pred"] = pred["pred"] > 0.5
# pred["pred"] = pred["pred"].astype(int)

# pd.crosstab(index=pred["lab"], columns=pred["pred"])

def pred_to_piece(prediction):
    fen_posibilities = 'RNBQKPrnbqkp'
    pred_bool = list(prediction)
    return fen_posibilities[pred_bool.index(max(pred_bool))]

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image_test[i])
  plt.title(pred_to_piece(label_test[i]))
  plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-23a5ace9bdeb> in <module>
#       3   ax = plt.subplot(5, 5, i + 1)
#       4   plt.imshow(image_test[i])
# ----> 5   plt.title(pred_to_piece(label_test[i]))
#       6   plt.axis("off")
#
# NameError: name 'pred_to_piece' is not defined

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image_test[i])
  plt.title(pred_to_piece(predictions[i]))
  plt.axis("off")

# %%
import glob
current_working_dir = os.getcwd().replace('\\','/')
path_img_demo = current_working_dir + "/03_demo_data"
path_img_demo_squares = path_img_demo + "/squares"
img_files = []
imgs = []
for img in glob.iglob(path_img_demo_squares + '**/*.png', recursive=True):
    img_files.append(img)

# %%
def read_image(image_file):
        image = tf.io.read_file(image_file)
        image = tf.image.decode_image(image, channels=3, dtype=tf.float32)
        return image

# %%
for img_path in img_files:
    img = read_image(img_path)
    imgs.append(img.numpy())

# %%
demo_img = np.array(tuple(imgs))

# %%
demo_pred = model.predict(demo_img)

# %%
pred_lit = [pred_to_piece(p) for p in demo_pred]

# %%
pred_lit
# Out:
# ['b',
#  'p',
#  'B',
#  'B',
#  'B',
#  'q',
#  'P',
#  'p',
#  'p',
#  'b',
#  'p',
#  'p',
#  'b',
#  'p',
#  'Q',
#  'r',
#  'P',
#  'p',
#  'B',
#  'P',
#  'B',
#  'P',
#  'r',
#  'P',
#  'p',
#  'p',
#  'P',
#  'b',
#  'P',
#  'p',
#  'R',
#  'r',
#  'N',
#  'p',
#  'N',
#  'p',
#  'p',
#  'P',
#  'p',
#  'R',
#  'p',
#  'n',
#  'p',
#  'P',
#  'p',
#  'B',
#  'b',
#  'n',
#  'P',
#  'B',
#  'p',
#  'b',
#  'p',
#  'K',
#  'B',
#  'P',
#  'K',
#  'N',
#  'k',
#  'R',
#  'P',
#  'B',
#  'B',
#  'b']

# %%
plt.figure(figsize=(10, 10))
for i in range(64):
  ax = plt.subplot(8, 8, i + 1)
  plt.imshow(imgs[i])
  plt.title(pred_lit[i])
  plt.axis("off")
