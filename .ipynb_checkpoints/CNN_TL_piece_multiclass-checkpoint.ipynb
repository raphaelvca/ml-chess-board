# %%
# piece classifier

import os
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from Creator_dataset import Creator_dataset
from tensorflow.keras import datasets, layers, models, optimizers
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
# from keras_visualizer import visualizer 
#new
# import tensorflow_addons as tfa
# from focal_loss import BinaryFocalLoss
# from focal_loss import SparseCategoricalFocalLoss

# %%
AUTOTUNE = tf.data.AUTOTUNE
creator_dataset = Creator_dataset(32) 
train_ds = creator_dataset.create_dataset("piece", "piece_train")
test_ds = creator_dataset.create_dataset("piece", "piece_test")
val_ds = creator_dataset.create_dataset("piece", "piece_val")

image_batch_train, label_batch_train = next(iter(train_ds))
image_batch_test, label_batch_test = next(iter(test_ds))
image_batch_val, label_batch_val = next(iter(val_ds))

image_train = np.concatenate([x1 for x1, y1 in train_ds], axis=0)
label_train = np.concatenate([y2 for x2, y2 in train_ds], axis=0)
image_val = np.concatenate([x for x, y in val_ds], axis=0)
label_val = np.concatenate([y for x, y in val_ds], axis=0)
image_test = np.concatenate([x for x, y in test_ds], axis=0)
label_test = np.concatenate([y for x, y in test_ds], axis=0)
# Out:
# --------------------
# Dataset <built-in function dir>
# piece_train	31200	975 bt. x 32 bt.size: done
# --------------------
# --------------------
# Dataset <built-in function dir>
# piece_test	3000	94 bt. x 32 bt.size: done
# --------------------
# --------------------
# Dataset <built-in function dir>
# piece_val	3000	94 bt. x 32 bt.size: done
# --------------------

# %%
## Transforming labels to correct format
num_classes = 12
#label_train = to_categorical(label_train, num_classes=num_classes)
#label_test = to_categorical(label_test, num_classes=num_classes)
#label_val = to_categorical(label_val, num_classes=num_classes)
#label_batch_train = to_categorical(label_batch_train, num_classes=num_classes)
#label_batch_test = to_categorical(label_batch_test, num_classes=num_classes)
#label_batch_val = to_categorical(label_batch_val, num_classes=num_classes)

# Achtung mit der Batchsize
# print(image_train.shape)
# print(label_train.shape)
# print(image_val.shape)
# print(label_val.shape)
# print(image_test.shape)
# print(label_test.shape)

train_dataset = train_ds.prefetch(buffer_size=AUTOTUNE)
validation_dataset = val_ds.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
#pd.DataFrame({"piece": [char for char in 'RNBQKPrnbqkp'],
#            "freq" : list(sum(label_train)),
#            "freq" : list(sum(label_test)),
#            "freq" : list(sum(label_val))})

# %%
#CNN
model = tf.keras.models.Sequential([
tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(100, 100, 3)),
tf.keras.layers.MaxPooling2D(2, 2),
tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(12, activation='softmax')])



model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              #loss=BinaryFocalLoss(gamma=2),
              metrics=['accuracy'])


history = model.fit(image_train, 
                    label_train, 
                    epochs=50, 
                    validation_data=(image_val, label_val),
                    callbacks=[callback])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# Epoch 1/50
# /home/clusterusers/rriege/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 975/975 [==============================] - 7s 7ms/step - loss: 1.7031 - accuracy: 0.3544 - val_loss: 1.4060 - val_accuracy: 0.4973
# Epoch 2/50
# 975/975 [==============================] - 6s 6ms/step - loss: 1.1435 - accuracy: 0.5838 - val_loss: 1.0251 - val_accuracy: 0.6353
# Epoch 3/50
# 975/975 [==============================] - 6s 6ms/step - loss: 0.8669 - accuracy: 0.6959 - val_loss: 0.7792 - val_accuracy: 0.7380
# Epoch 4/50
# 975/975 [==============================] - 6s 6ms/step - loss: 0.6827 - accuracy: 0.7672 - val_loss: 0.6530 - val_accuracy: 0.7833
# Epoch 5/50
# 187/975 [====>.........................] - ETA: 4s - loss: 0.5705 - accuracy: 0.8130
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-8ab9e9afb4ea> in <module>
#      26
#      27
# ---> 28 history = model.fit(image_train,
#      29                     label_train,
#      30                     epochs=50,
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Transfer Learning Xception
n_classes = 12
#base_model = keras.applications.ResNet50(input_shape = (100, 100, 3),
base_model = keras.applications.xception.Xception(
                                         weights="imagenet",
                                         include_top=False)
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(n_classes, activation="softmax")(avg)
model = keras.models.Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

#optimizer = keras.optimizers.SGD(learning_rate=0.2, momentum=0.9, decay=0.01)
model.compile(loss = "sparse_categorical_crossentropy", 
              #optimizer=optimizer,
              optimizer = "adam",
              metrics=["accuracy"])

# model.summary()
#optimizer = keras.optimizers.SGD(learning_rate=0.2, momentum=0.9, decay=0.01)
model.compile(loss = "sparse_categorical_crossentropy", 
              #optimizer=optimizer,
              optimizer = "adam",
              metrics=["accuracy"])

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)


history = model.fit(image_train, 
                    label_train, 
                    epochs=50, 
                    validation_data=(image_val, label_val),
                    callbacks=[callback])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# Epoch 1/50
# 975/975 [==============================] - 18s 17ms/step - loss: 1.2894 - accuracy: 0.5663 - val_loss: 1.0798 - val_accuracy: 0.6373
# Epoch 2/50
# 329/975 [=========>....................] - ETA: 8s - loss: 0.9990 - accuracy: 0.6660
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c460dcaeb4b9> in <module>
#      28
#      29
# ---> 30 history = model.fit(image_train,
#      31                     label_train,
#      32                     epochs=50,
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Transfer Learning Xception 2
num_classes = 12
#base_model = keras.applications.ResNet50(input_shape = (100, 100, 3),
base_model = keras.applications.xception.Xception(
                                         weights="imagenet",
                                         include_top=False)

inputs = tf.keras.Input(shape = (100,100,3))
# Works
# x = base_model(inputs)
# x = layers.Flatten()(x)
# x = layers.Dense(256)(x)
# x = layers.Dropout(0.5)(x)
# outputs = layers.Dense(1, activation='softmax')(x)

x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs,outputs)

for layer in base_model.layers:
    layer.trainable = False


# model.summary()
#optimizer = keras.optimizers.SGD(learning_rate=0.2, momentum=0.9, decay=0.01)
model.compile(loss = "sparse_categorical_crossentropy", 
              #optimizer=optimizer,
              optimizer = "adam",
              metrics=["accuracy"])

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)


history = model.fit(image_train, 
                    label_train, 
                    epochs=50, 
                    validation_data=(image_val, label_val),
                    callbacks=[callback])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# Epoch 1/50
# 421/975 [===========>..................] - ETA: 8s - loss: 1.9119 - accuracy: 0.3565
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1ba077766589> in <module>
#      39
#      40
# ---> 41 history = model.fit(image_train,
#      42                     label_train,
#      43                     epochs=50,
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# ~/.local/lib/python3.8/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/.local/lib/python3.8/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# Transfer Learning ResNet50
num_classes = 12
base_model = keras.applications.ResNet50(input_shape = (100, 100, 3),
                                         weights="imagenet",
                                         include_top=False)

inputs = tf.keras.Input(shape = (100,100,3))

x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs,outputs)

for layer in base_model.layers:
    layer.trainable = False

#optimizer = keras.optimizers.SGD(learning_rate=0.2, momentum=0.9, decay=0.01)
model.compile(loss = "sparse_categorical_crossentropy", 
              #optimizer=optimizer,
              optimizer = "adam",
              metrics=["accuracy"])

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

image_train_res = tf.keras.applications.resnet50.preprocess_input(image_train)
image_val_res = tf.keras.applications.resnet50.preprocess_input(image_val)

history = model.fit(image_train_res, 
                    label_train, 
                    epochs=50, 
                    validation_data=(image_val_res, label_val),
                    callbacks=[callback])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

#val_acc = 0.0833
# Out:
# Epoch 1/50
# 975/975 [==============================] - 20s 18ms/step - loss: 2.5453 - accuracy: 0.0803 - val_loss: 2.5074 - val_accuracy: 0.0833
# Epoch 2/50
# 975/975 [==============================] - 16s 16ms/step - loss: 2.5056 - accuracy: 0.0797 - val_loss: 2.5007 - val_accuracy: 0.0833
# Epoch 3/50
# 975/975 [==============================] - 15s 16ms/step - loss: 2.4982 - accuracy: 0.0804 - val_loss: 2.4954 - val_accuracy: 0.0833
# Epoch 4/50
# 975/975 [==============================] - 17s 17ms/step - loss: 2.4935 - accuracy: 0.0795 - val_loss: 2.4913 - val_accuracy: 0.0833
# Epoch 5/50
# 975/975 [==============================] - 20s 20ms/step - loss: 2.4907 - accuracy: 0.0799 - val_loss: 2.4888 - val_accuracy: 0.0833
# Epoch 6/50
# 975/975 [==============================] - 19s 19ms/step - loss: 2.4880 - accuracy: 0.0821 - val_loss: 2.4869 - val_accuracy: 0.0833
# Epoch 7/50
# 975/975 [==============================] - 20s 20ms/step - loss: 2.4868 - accuracy: 0.0798 - val_loss: 2.4860 - val_accuracy: 0.0833
# Epoch 8/50
# 975/975 [==============================] - 19s 20ms/step - loss: 2.4859 - accuracy: 0.0825 - val_loss: 2.4854 - val_accuracy: 0.0833
# Epoch 9/50
# 975/975 [==============================] - 19s 20ms/step - loss: 2.4854 - accuracy: 0.0850 - val_loss: 2.4851 - val_accuracy: 0.0833
# Epoch 10/50
# 220/975 [=====>........................] - ETA: 13s - loss: 2.4852 - accuracy: 0.0801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-9b02f5d00f6b> in <module>
#      32 image_val_res = tf.keras.applications.resnet50.preprocess_input(image_val)
#      33
# ---> 34 history = model.fit(image_train_res,
#      35                     label_train,
#      36                     epochs=50,
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
conv_base = keras.applications.VGG16(
                    weights = 'imagenet',
                    include_top = False#,
                    #input_shape = (100,100,3)
                 )
inputs = tf.keras.Input(shape = (100,100,3))

x = conv_base(inputs)
x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs,outputs)

for layer in conv_base.layers:
    layer.trainable = False


model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizers.Nadam(lr=2e-5), metrics=['acc'])
model.summary()

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

#image_train_vgg = tf.keras.applications.vgg16.preprocess_input(image_train)
#image_val_vgg = tf.keras.applications.vgg16.preprocess_input(image_val)
history = model.fit(image_train, 
                    label_train, 
                    epochs=50, 
                    validation_data=(image_val, label_val),
                    callbacks=[callback])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 100, 100, 3)]     0
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten_5 (Flatten)         (None, 4608)              0
#
#  dense_18 (Dense)            (None, 256)               1179904
#
#  dense_19 (Dense)            (None, 128)               32896
#
#  dense_20 (Dense)            (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_21 (Dense)            (None, 12)                780
#
# =================================================================
# Total params: 15,936,524
# Trainable params: 1,221,836
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# 975/975 [==============================] - 18s 16ms/step - loss: 2.9666 - acc: 0.0820 - val_loss: 2.5542 - val_acc: 0.0967
# Epoch 2/50
# 975/975 [==============================] - 14s 15ms/step - loss: 2.5477 - acc: 0.0812 - val_loss: 2.5412 - val_acc: 0.0833
# Epoch 3/50
# 975/975 [==============================] - 15s 15ms/step - loss: 2.5363 - acc: 0.0833 - val_loss: 2.5317 - val_acc: 0.0833
# Epoch 4/50
# 975/975 [==============================] - 15s 15ms/step - loss: 2.5281 - acc: 0.0842 - val_loss: 2.5245 - val_acc: 0.0837
# Epoch 5/50
# 975/975 [==============================] - 14s 15ms/step - loss: 2.5218 - acc: 0.0840 - val_loss: 2.5190 - val_acc: 0.0833
# Epoch 6/50
# 975/975 [==============================] - 15s 15ms/step - loss: 2.5169 - acc: 0.0833 - val_loss: 2.5149 - val_acc: 0.0833
# Epoch 7/50
# 975/975 [==============================] - 15s 15ms/step - loss: 2.5132 - acc: 0.0833 - val_loss: 2.5117 - val_acc: 0.0833
# Epoch 8/50
# 975/975 [==============================] - 15s 15ms/step - loss: 2.5103 - acc: 0.0833 - val_loss: 2.5091 - val_acc: 0.0833
# Epoch 9/50
# 905/975 [==========================>...] - ETA: 0s - loss: 2.5080 - acc: 0.0824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-07c868d9f79c> in <module>
#      28 #image_train_vgg = tf.keras.applications.vgg16.preprocess_input(image_train)
#      29 #image_val_vgg = tf.keras.applications.vgg16.preprocess_input(image_val)
# ---> 30 history = model.fit(image_train,
#      31                     label_train,
#      32                     epochs=50,
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# ~/.local/lib/python3.8/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/.local/lib/python3.8/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
test_loss, test_acc = model.evaluate(image_test,  label_test, verbose=2)

print(test_loss)
print(test_acc)
# Out:
# 94/94 - 1s - loss: 1.0140 - accuracy: 0.7227 - 1s/epoch - 14ms/step
# 1.0140271186828613
# 0.7226666808128357

# %%
predictions = model.predict(image_test)
pred_bool = list(predictions)
print(np.argmax(pred_bool[0]))
# Out:
# 5

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(12))
  plt.yticks([])
  thisplot = plt.bar(range(12), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], label_test, image_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  label_test)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], label_test, image_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], label_test)
plt.tight_layout()
plt.show()

# %%
#predlist = predictions.tolist()
#predlist2 = [x[0] for x in predlist]

# pred = pd.DataFrame({"pred": predlist2, "lab": label_test})

# pred["pred"] = pred["pred"] > 0.5
# pred["pred"] = pred["pred"].astype(int)

# pd.crosstab(index=pred["lab"], columns=pred["pred"])

def pred_to_piece(prediction):
    fen_posibilities = 'RNBQKPrnbqkp'
    pred_bool = list(prediction)
    return fen_posibilities[pred_bool.index(max(pred_bool))]

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image_test[i])
  plt.title(pred_to_piece(label_test[i]))
  plt.axis("off")

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image_test[i])
  plt.title(pred_to_piece(predictions[i]))
  plt.axis("off")
